# %%
#Title,views,video_link,Video_thumbnail
#Read this link
#https://www.scrapingbee.com/blog/web-scraping-youtube/?utm_source=related_content

# %%
import time
import pprint

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
C

channel_title = driver.find_element(By.XPATH, '//yt-formatted-string[contains(@class, "ytd-channel-name")]').text
handle = driver.find_element(By.XPATH, '//yt-formatted-string[@id="channel-handle"]').text
subscriber_count = driver.find_element(By.XPATH, '//yt-formatted-string[@id="subscriber-count"]').text

WAIT_IN_SECONDS = 5
last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    # Scroll to the bottom of page
    driver.execute_script("window.scrollTo(0, arguments[0]);", last_height)
    # Wait for new videos to show up
    time.sleep(WAIT_IN_SECONDS)
    
    # Calculate new document height and compare it with last height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


thumbnails = driver.find_elements(By.XPATH, '//a[@id="thumbnail"]/yt-image/img')
views = driver.find_elements(By.XPATH,'//div[@id="metadata-line"]/span[1]')
titles = driver.find_elements(By.ID, "video-title")
links = driver.find_elements(By.ID, "video-title-link")

videos = []
for title, view, thumb, link in zip(titles, views, thumbnails, links):
    video_dict = {
        'title': title.text,
        'views': view.text,
        'thumbnail': thumb.get_attribute('src'),
        'link': link.get_attribute('href')
    }
    videos.append(video_dict)

print(videos)
# Out:
# [{'title': 'How Raghav Got 6 Offers In Data Science Coming From Non Technical Domain @iNeuroniNtelligence', 'views': '6.4K views', 'thumbnail': 'https://i.ytimg.com/vi/0vnaw8soiO4/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARhlIE8oRjAP&rs=AOn4CLDxVf_d7WS2LepgbY1yyDyXLFVm7Q', 'link': 'https://www.youtube.com/watch?v=0vnaw8soiO4'}, {'title': 'Sucessful Transition Story From Mechanical Eng ,UPSC Aspirant To Data Analyst Apprentice At Google', 'views': '4.7K views', 'thumbnail': 'https://i.ytimg.com/vi/AcAmDZcmVMM/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARhyIE8oNzAP&rs=AOn4CLAoE7LxGKpimaStro3mUVyzzhK_1w', 'link': 'https://www.youtube.com/watch?v=AcAmDZcmVMM'}, {'title': 'Can We Earn More From FreeLancing Than Full time Jobs? Steps To Start Your Free Lancing Career', 'views': '7.7K views', 'thumbnail': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDbzZwpScD2qnuBY-bQVwcLwTgM3A', 'link': 'https://www.youtube.com/watch?v=MQDqGpmB_kQ'}, {'title': 'Google Chatbot Alternative To ChatGPT- Who Will Win?', 'views': '15K views', 'thumbnail': 'https://i.ytimg.com/vi/ePWQwNWwWfQ/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB6RM-lyyzvSyi4kCZy76AX2vSSCw', 'link': 'https://www.youtube.com/watch?v=ePWQwNWwWfQ'}, {'title': 'How To Build Ideas For Real World Data Science Projects For Interviews', 'views': '8.9K views', 'thumbnail': 'https://i.ytimg.com/vi/qgf4_5ximzI/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDO2CfgmW0IefeSX86qY3uDl7OHRA', 'link': 'https://www.youtube.com/watch?v=qgf4_5ximzI'}, {'title': 'Reality Of Data Science Work- What We Learn Vs What We Work In Industries', 'views': '23K views', 'thumbnail': 'https://i.ytimg.com/vi/HbLA-8vvc_U/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARhlIFEoQDAP&rs=AOn4CLCTlDr4oIP0_tA5ihvMsmhUNL-02g', 'link': 'https://www.youtube.com/watch?v=HbLA-8vvc_U'}, {'title': 'AvgWord2vec Indepth Intuition And Practical Implementation', 'views': '2.9K views', 'thumbnail': 'https://i.ytimg.com/vi/cyvkMFZnheo/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDcDR7N_8RmXJIXfxvogijlpjAVZQ', 'link': 'https://www.youtube.com/watch?v=cyvkMFZnheo'}, {'title': 'Why Big Tech Companies Are Facing Massive Layoffs?', 'views': '32K views', 'thumbnail': 'https://i.ytimg.com/vi/8nMWP2IiIzg/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBQgqgW_ZWEmTuoXsNvkmXrkxCLGA', 'link': 'https://www.youtube.com/watch?v=8nMWP2IiIzg'}, {'title': 'Word Embeddings, Word2Vec And CBOW Indepth Intuition And Working- Part 1 | NLP For Machine Learning', 'views': '4.7K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=Q95SIG4g7SA'}, {'title': 'Demo Of AI Powered Nvidia Broadcast Eye Contact', 'views': '8.3K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=ZX79iA7CILE'}, {'title': 'My Thoughts On Recent Layoffs And Recession', 'views': '55K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=I5UFW1ob_U4'}, {'title': 'PCA Indepth Geometric And Mathematical InDepth Intuition ML Algorithms', 'views': '8K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=H99JRtDDnvk'}, {'title': 'I Used Chatgpt To Create My Own Private Web Browser', 'views': '19K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=cTkPug1q8Pk'}, {'title': "Data Collection Stratergy For Machine Learning Projects With API's- RapidAPI", 'views': '10K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=G7W1LzhbfGE'}, {'title': 'Why To Choose Data Science As A Career In 2023?', 'views': '18K views', 'thumbnail': None, 'link': 'https://www.youtube.com/watch?v=dcGwuETxhrk'}, {'title': 'The Ultimate 2023 Data Analyst Roadmap: From Zero to Hero|Krish Naik', 'views': '45K views', 'thumbnail' ...

# %%
number_of_videos=len(videos)
number_of_videos
# Out:
# 1335

# %%
#Go to the each link and give all detail

# %%
#Import packages
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
youtube_video_url = "https://www.youtube.com/watch?v=0vnaw8soiO4&list=UULFNU_lfiiWBdtULKOw6X0Dig"

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\Srikanta\Desktop\FullStackDataScience\Challenges\IneuronScrapper\chromedriver')
# Out:
# C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17884\899536952.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\Srikanta\Desktop\FullStackDataScience\Challenges\IneuronScrapper\chromedriver')

# %%
driver.implicitly_wait(2)

# %%
driver.get(youtube_video_url)
time.sleep(5)

# %%
# ## Pause youtube video if needed

# pause = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, 'ytp-play-button')))

# pause.click()
# time.sleep(0.2)
# pause.click()
# time.sleep(4)

# %%
#infinity scroll
WAIT_IN_SECONDS = 5
last_height = driver.execute_script("return document.documentElement.scrollHeight")
#Why i am getting error with same ineuron infinity code
#Because in ineuron we search as perbody but in youtube we have go as per element
### current_height=driver.execute_script('return document.body.scrollHeight;')

while True:
    # Scroll to the bottom of page
    driver.execute_script("window.scrollTo(0, arguments[0]);", last_height)
    # Wait for new videos to show up
    time.sleep(WAIT_IN_SECONDS)
    
    # Calculate new document height and compare it with last height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
## title of video
video_title = driver.find_element(By.NAME, 'title').get_attribute('content')
video_title
# Out:
# 'How Raghav Got 6 Offers In Data Science Coming From Non Technical Domain @iNeuroniNtelligence'

# %%
## owner of video
video_owner = driver.find_elements(By.XPATH, '//*[@id="text"]/a')

# %%
video_owner[0].text
# Out:
# 'Krish Naik'

# %%
# total comments with replies
video_comment_with_replies = driver.find_element(By.XPATH, '//*[@id="count"]/yt-formatted-string/span[1]').text + ' Comments'

# %%
video_comment_with_replies
# Out:
# '26 Comments'

# %%
# total number of likes

# %%
total_likes=driver.find_element(By.XPATH, '//*[@id="segmented-like-button"]')
total_likes.text
# Out:
# '280'

# %%
## Scraping all the comments
users = driver.find_elements(By.XPATH, '//*[@id="author-text"]/span')
comments = driver.find_elements(By.XPATH, '//*[@id="content-text"]')

# %%
users
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="f5454a44-d394-4e8e-adb9-ec6a896d5109")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="027c8cc4-6834-4650-bff9-c3644d5c802c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="9cd35aed-4406-47c1-9d77-1914edc6a1c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="f93d1302-14c5-4be4-91e7-ee3bd46d8099")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="88ebddfc-187a-4c32-b7f5-f520ff122681")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="b944e2ef-cc32-4ced-8356-6a2b9831ef57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="2a4a0c7f-aa6b-49e6-bc0f-78570350dd80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="d60c7735-85d4-4ff6-b71f-5ebcd0b0f6e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="9c60ecac-2da5-4f1e-891e-0414463ee42e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="bc86dfed-2e21-4fb6-9d46-ce73461cbf64")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="37e676af-265c-468f-9bfc-fecffe57d13a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="75e51c8c-93cf-4af3-8c55-e7ba9c12cfea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="f554d864-fa86-4689-bcab-260ea2d19362")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="c23b5104-5f17-435d-a423-08d810c21cd0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="eaa09206-d4e3-494c-8ac6-c4b2167bc827")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="b9e02a05-a713-417e-9889-ac0b00ede436")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="5ae6081b-9e4a-4a4a-8631-d2a149a959ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="091c2ce9-a851-478c-ab22-00003320304c")>]

# %%
comments
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="43636044-313e-4b63-bf8e-136cb6c82761")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="f581ef01-c92e-4a8e-9f29-c64c52bfaae9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="57b9a5e7-3051-4b5f-9904-e765e3344c04")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="5216f1cb-891a-408d-972a-76f4c084a967")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="e5205982-753b-452b-bb7a-f828deaf8f6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="8324a2f5-d4e2-4173-a476-5b80f18f5d3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="c1893dad-8dfe-4638-bd15-a828c05871b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="0618a815-c474-4baf-8ce2-333fd785d29d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="a015c5a6-9d88-43d0-ab3a-e8409dc7b274")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="d47606cc-5aca-462e-adeb-c8168db30f44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="ffb6f90d-a9e0-4ad0-a2df-791f19de64d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="31000c71-c7cc-4ea5-b062-7a616c44876f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="b03ccfae-4210-4f4a-9a20-faae7fafd732")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="31a59290-be35-4b19-8406-3e9fa68a2ec7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="45edfb54-0070-4192-aa4a-75ad8a8f716e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="d1f9061e-ed71-4066-8378-47bcaea97d0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="a20abe48-e5ae-4293-b2d7-6e48020fa8a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5964fa8184957effbf14201a86a3c7f7", element="86005291-fcd7-43a4-81d7-6f858206b921")>]

# %%
users[0].text
# Out:
# '@AkshmaNargotra'

# %%
comments[0].text
# Out:
# 'Hardwork pays off\nKeep it up Raghav'

# %%
len(users)
# Out:
# 18

# %%
users[1].text
# Out:
# '@ameeraharis3126'

# %%
#!pip install webdriver_manager

# %%
#pip uninstall pprintpp
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
